# %% [markdown]
# # Notebook 05: Explainability - SHAP & LIME Analysis
#
# Provides model interpretability using:
# - **SHAP**: Global and local feature importance for all models
# - **LIME**: Local explanation of individual predictions
# - **Cross-model feature importance comparison**

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

from src.feature_engineering import load_prepared_data, prepare_features
from src.ml_models import load_model, predict_with_model
from src.explainability import (
    full_shap_analysis, full_lime_analysis,
    cross_model_feature_importance
)

# %% [markdown]
# ## 5.1 Load Data & Models

# %%
FORMAT_KEY = 'mens_odi'
train_df, test_df = load_prepared_data(FORMAT_KEY)

X_train, y_train, feature_names = prepare_features(train_df)
X_test, y_test, _ = prepare_features(test_df)

# Load trained models
models = {}
for name in ['xgboost', 'random_forest', 'lightgbm', 'neural_network']:
    try:
        model, scaler = load_model(name, format_key=FORMAT_KEY)
        models[name] = {'model': model, 'scaler': scaler}
        print(f"Loaded: {name}")
    except FileNotFoundError:
        print(f"Not found: {name}")

print(f"\nFeatures: {feature_names}")
print(f"Test samples: {len(X_test)}")
# Out:
# 2026-02-08 23:10:28,185 - INFO - Feature matrix: (103930, 22), Target: (103930,)
# 2026-02-08 23:10:28,188 - INFO - Feature matrix: (25392, 22), Target: (25392,)
# Loaded: xgboost
# Loaded: random_forest
# Loaded: lightgbm
# Not found: neural_network
#
# Features: ['overs_completed', 'overs_remaining', 'current_score', 'wickets_fallen', 'wickets_in_hand', 'current_run_rate', 'recent_run_rate_5', 'scoring_acceleration', 'boundary_percentage', 'dot_ball_percentage', 'partnership_runs', 'is_powerplay', 'is_middle_overs', 'is_death_overs', 'recent_wickets_5', 'cumulative_boundaries', 'cumulative_sixes', 'innings_progress', 'year', 'toss_bat_first', 'resource_pct_dls', 'dls_predicted_final']
# Test samples: 25392

# %% [markdown]
# ## 5.2 SHAP Analysis - XGBoost

# %%
if 'xgboost' in models:
    xgb_shap, xgb_explainer = full_shap_analysis(
        models['xgboost']['model'], X_test,
        model_name='XGBoost',
        model_type='tree',
        format_key=FORMAT_KEY,
        sample_size=1000,
    )
    print("XGBoost SHAP analysis complete")
# Out:
# 2026-02-08 23:10:32,562 - INFO - Computing SHAP values for XGBoost (1000 samples)...
# 2026-02-08 23:10:34,078 - INFO - Saved SHAP summary plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_summary_xgboost.png
# 2026-02-08 23:10:34,143 - INFO - Saved SHAP bar plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_bar_xgboost.png
# 2026-02-08 23:10:34,217 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_dls_predicted_final_xgboost.png
# 2026-02-08 23:10:34,297 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_current_run_rate_xgboost.png
# 2026-02-08 23:10:34,374 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_resource_pct_dls_xgboost.png
# 2026-02-08 23:10:34,454 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_year_xgboost.png
# 2026-02-08 23:10:34,529 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_wickets_fallen_xgboost.png
# 2026-02-08 23:10:34,670 - INFO - Saved SHAP waterfall plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_waterfall_0_xgboost.png
# 2026-02-08 23:10:34,776 - INFO - Saved SHAP waterfall plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_waterfall_500_xgboost.png
# 2026-02-08 23:10:34,883 - INFO - Saved SHAP waterfall plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_waterfall_999_xgboost.png
# XGBoost SHAP analysis complete

# %% [markdown]
# ## 5.3 SHAP Analysis - Random Forest

# %%
if 'random_forest' in models:
    rf_shap, rf_explainer = full_shap_analysis(
        models['random_forest']['model'], X_test,
        model_name='RandomForest',
        model_type='tree',
        format_key=FORMAT_KEY,
        sample_size=1000,
    )
    print("Random Forest SHAP analysis complete")
# Out:
# 2026-02-08 23:10:34,888 - INFO - Computing SHAP values for RandomForest (1000 samples)...
# 2026-02-08 23:10:44,586 - INFO - Saved SHAP summary plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_summary_randomforest.png
# 2026-02-08 23:10:44,649 - INFO - Saved SHAP bar plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_bar_randomforest.png
# 2026-02-08 23:10:44,732 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_dls_predicted_final_randomforest.png
# 2026-02-08 23:10:44,812 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_current_run_rate_randomforest.png
# 2026-02-08 23:10:44,891 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_dot_ball_percentage_randomforest.png
# 2026-02-08 23:10:44,970 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_boundary_percentage_randomforest.png
# 2026-02-08 23:10:45,044 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_wickets_in_hand_randomforest.png
# 2026-02-08 23:10:45,155 - INFO - Saved SHAP waterfall plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_waterfall_0_randomforest.png
# 2026-02-08 23:10:45,267 - INFO - Saved SHAP waterfall plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_waterfall_500_randomforest.png
# 2026-02-08 23:10:45,421 - INFO - Saved SHAP waterfall plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_waterfall_999_randomforest.png
# Random Forest SHAP analysis complete

# %% [markdown]
# ## 5.4 SHAP Analysis - LightGBM

# %%
if 'lightgbm' in models:
    lgb_shap, lgb_explainer = full_shap_analysis(
        models['lightgbm']['model'], X_test,
        model_name='LightGBM',
        model_type='tree',
        format_key=FORMAT_KEY,
        sample_size=1000,
    )
    print("LightGBM SHAP analysis complete")
# Out:
# 2026-02-08 23:10:45,427 - INFO - Computing SHAP values for LightGBM (1000 samples)...
# 2026-02-08 23:10:45,648 - INFO - Saved SHAP summary plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_summary_lightgbm.png
# 2026-02-08 23:10:45,711 - INFO - Saved SHAP bar plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_bar_lightgbm.png
# 2026-02-08 23:10:45,790 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_dls_predicted_final_lightgbm.png
# 2026-02-08 23:10:45,865 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_current_run_rate_lightgbm.png
# 2026-02-08 23:10:45,938 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_resource_pct_dls_lightgbm.png
# 2026-02-08 23:10:46,014 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_wickets_fallen_lightgbm.png
# 2026-02-08 23:10:46,091 - INFO - Saved SHAP dependence plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_dep_year_lightgbm.png
# 2026-02-08 23:10:46,201 - INFO - Saved SHAP waterfall plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_waterfall_0_lightgbm.png
# 2026-02-08 23:10:46,309 - INFO - Saved SHAP waterfall plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_waterfall_500_lightgbm.png
# 2026-02-08 23:10:46,471 - INFO - Saved SHAP waterfall plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_shap_waterfall_999_lightgbm.png
# LightGBM SHAP analysis complete

# %% [markdown]
# ## 5.5 SHAP Analysis - Neural Network
#
# Uses KernelExplainer (slower, but works for any model).

# %%
if 'neural_network' in models:
    # NN SHAP is slower - use smaller sample
    nn_shap, nn_explainer = full_shap_analysis(
        models['neural_network']['model'], X_test,
        model_name='NeuralNetwork',
        model_type='kernel',
        scaler=models['neural_network']['scaler'],
        format_key=FORMAT_KEY,
        sample_size=200,  # Smaller for KernelExplainer
    )
    print("Neural Network SHAP analysis complete")

# %% [markdown]
# ## 5.6 Cross-Model Feature Importance

# %%
# Collect all SHAP values
shap_results = {}
if 'xgboost' in models:
    shap_results['XGBoost'] = xgb_shap
if 'random_forest' in models:
    shap_results['RandomForest'] = rf_shap
if 'lightgbm' in models:
    shap_results['LightGBM'] = lgb_shap
if 'neural_network' in models:
    shap_results['NeuralNetwork'] = nn_shap

if shap_results:
    importance_df = cross_model_feature_importance(
        shap_results, feature_names,
        format_key=FORMAT_KEY,
        top_n=15
    )
    print("\nCross-model feature importance:")
    print(importance_df)
# Out:
# 2026-02-08 23:10:46,587 - INFO - Saved cross-model importance: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_cross_model_importance.png
# Cross-model feature importance:
#                         XGBoost  RandomForest  LightGBM
# overs_remaining        0.002124      0.014022  0.019889
# recent_wickets_5       0.019380      0.014752  0.022366
# current_score          0.006794      0.038163  0.019149
# partnership_runs       0.016877      0.030939  0.016991
# overs_completed        0.031361      0.013756  0.025403
# recent_run_rate_5      0.000241      0.050443  0.047440
# cumulative_boundaries  0.021716      0.049834  0.049195
# wickets_in_hand        0.004101      0.136015  0.017249
# year                   0.108897      0.032672  0.134130
# boundary_percentage    0.060669      0.164295  0.051308
# dot_ball_percentage    0.057048      0.212840  0.075796
# wickets_fallen         0.092968      0.129945  0.136500
# resource_pct_dls       0.150825      0.101987  0.149238
# current_run_rate       0.330522      0.565149  0.361672
# dls_predicted_final    1.000000      1.000000  1.000000

# %% [markdown]
# ## 5.7 LIME Analysis

# %%
# LIME for XGBoost (best tree model typically)
if 'xgboost' in models:
    xgb_lime = full_lime_analysis(
        models['xgboost']['model'],
        X_train, X_test, y_test,
        model_name='XGBoost',
        format_key=FORMAT_KEY,
        n_instances=5,
    )
    print("XGBoost LIME analysis complete")
# Out:
# 2026-02-08 23:10:46,858 - INFO - Saved LIME plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_lime_0_xgboost.png
# 2026-02-08 23:10:46,865 - INFO - Saved LIME HTML: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_lime_0_xgboost.html
# 2026-02-08 23:10:47,123 - INFO - Saved LIME plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_lime_1_xgboost.png
# 2026-02-08 23:10:47,126 - INFO - Saved LIME HTML: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_lime_1_xgboost.html
# 2026-02-08 23:10:47,382 - INFO - Saved LIME plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_lime_2_xgboost.png
# 2026-02-08 23:10:47,385 - INFO - Saved LIME HTML: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_lime_2_xgboost.html
# 2026-02-08 23:10:47,642 - INFO - Saved LIME plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_lime_3_xgboost.png
# 2026-02-08 23:10:47,645 - INFO - Saved LIME HTML: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_lime_3_xgboost.html
# 2026-02-08 23:10:47,900 - INFO - Saved LIME plot: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_lime_4_xgboost.png
# 2026-02-08 23:10:47,903 - INFO - Saved LIME HTML: /Users/rajatdogra/Downloads/rajat_thesis/results/figures/mens_odi_lime_4_xgboost.html
# XGBoost LIME analysis complete

# %%
# LIME for Neural Network
if 'neural_network' in models:
    nn_lime = full_lime_analysis(
        models['neural_network']['model'],
        X_train, X_test, y_test,
        model_name='NeuralNetwork',
        scaler=models['neural_network']['scaler'],
        format_key=FORMAT_KEY,
        n_instances=5,
    )
    print("Neural Network LIME analysis complete")

# %% [markdown]
# ## 5.8 Key Findings Summary

# %%
print("="*60)
print("EXPLAINABILITY ANALYSIS SUMMARY")
print("="*60)

if shap_results:
    print("\nTop 5 features by SHAP importance (averaged across models):")
    avg_importance = importance_df.mean(axis=1).sort_values(ascending=False)
    for i, (feat, imp) in enumerate(avg_importance.head(5).items()):
        print(f"  {i+1}. {feat}: {imp:.3f}")

print("\nAll SHAP and LIME figures saved to results/figures/")
print("HTML LIME reports also saved for interactive exploration.")
print("\n✓ Explainability analysis complete!")
# Out:
# ============================================================
# EXPLAINABILITY ANALYSIS SUMMARY
# ============================================================
#
# Top 5 features by SHAP importance (averaged across models):
#   1. dls_predicted_final: 1.000
#   2. current_run_rate: 0.419
#   3. resource_pct_dls: 0.134
#   4. wickets_fallen: 0.120
#   5. dot_ball_percentage: 0.115
#
# All SHAP and LIME figures saved to results/figures/
# HTML LIME reports also saved for interactive exploration.
#
# ✓ Explainability analysis complete!
